# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\users2025\appdata\local\programs\python\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.listdir()
# Out:
# ['.git', '.ipynb_checkpoints', 'data', 'README.md', 'sales-analysis.ipynb']

# %%
# %pip install seaborn
import seaborn as sns
sns.set_style("whitegrid")
# Out:
# Requirement already satisfied: seaborn in c:\users\users2025\appdata\local\programs\python\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\users2025\appdata\local\programs\python\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
os.listdir()

# %%
os.mkdir("data")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.mkdir("data")
#
# FileExistsError: [WinError 183] Eine Datei kann nicht erstellt werden, wenn sie bereits vorhanden ist: 'data'

# %%
os.listdir("data")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("data/OnlineRetail.csv", encoding="latin1", parse_dates=["InvoiceDate"])
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()

# %%
# we can see, there are many null values in CustommerID and Description
# we have to remove tthe missung values 
# Remving the calncelled Orders 
# Removing rows with negative or zero values ( quantity, Price) 
#Keeping these values will lead to revenue miscalculation

# %%
# Data Cleaning 
# we need to create copy and keep the original raw data unchanged 
df_clean = df.copy()

# %%
# Remove rows with missing product descriptions
# These rows are not useful for product-level analysis
df_clean = df_clean.dropna(subset=["Description"])

# %%
# Remove rows with zero or negative quantity
# Negative quantity usually means returns or adjustments
df_clean = df_clean[df_clean["Quantity"] > 0]

# %%
# Rmove rows with zero or negative unit price , they do not represent the normal sales
df_clean= df_clean[df_clean["UnitPrice"] > 0]

# %%
# Remove rows with missing CutomerID, only for Customer analysis 
df_clean = df_clean.dropna(subset=["CustomerID"])

# %%
# we remove the cancelled order , statrts wiuth letter "c"
df_clean = df_clean[~df_clean["InvoiceNo"].astype(str).str.startswith("C")]

# %%
df_clean.shape
# Out:
# (530104, 8)

# %%
# after cleaning the dataset, we create main sales Matric 
#Revenue for each row = quantity sold * unit price
df_clean["Revenue"] = df_clean["Quantity"] * df_clean["UnitPrice"]
df_clean.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %%
total_revenue = df_clean["Revenue"].sum()
total_revenue
# Out:
# np.float64(10666684.544)

# %%
# Monthly Revenue Trend 
# we need to make sure InviceData is in datetime format
df_clean["InvoiceDate"] = pd.to_datetime(df_clean["InvoiceDate"])

# %%
# Create a Year-Month column for monthly grouping
# This keeps year and month together, which is better than month only
df_clean["YearMonth"] = df_clean["InvoiceDate"].dt.to_period("M")

# %%
# Group by month and calculate total revenue
monthly_revenue = df_clean.groupby("YearMonth")["Revenue"].sum().reset_index()

# %%
# Convert YearMonth back to text so it is easier to plot
monthly_revenue["YearMonth"] = monthly_revenue["YearMonth"].astype(str)

# %%
#show the first rows
monthly_revenue.head()
# Out:
#   YearMonth     Revenue
# 0   2010-12  823746.140
# 1   2011-01  691364.560
# 2   2011-02  523631.890
# 3   2011-03  717639.360
# 4   2011-04  537808.621

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(monthly_revenue["YearMonth"], monthly_revenue["Revenue"], marker="o")
plt.xticks(rotation=45)
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.tight_layout()
plt.show()

# %%
# Group by product description and sum total revenue for each product
top_customers = df_clean.groupby("CustomerID")["Revenue"].sum().reset_index()

# %%
# sort the Revenue descending 
top_customers = top_customers.sort_values(by="Revenue",ascending=False)

# %%
#keep top 10 countries 
top_10_customers = top_customers.head(10)
top_10_customers
# Out:
#       CustomerID    Revenue
# 1689     14646.0  280206.02
# 4201     18102.0  259657.30
# 3728     17450.0  194550.79
# 3008     16446.0  168472.50
# 1879     14911.0  143825.06
# 55       12415.0  124914.53
# 1333     14156.0  117379.63
# 3771     17511.0   91062.38
# 2702     16029.0   81024.84
# 0        12346.0   77183.60

# %%
# Group by product description and sum the total revenue for each product
top_products = df_clean.groupby("Description")["Revenue"].sum().reset_index()

# %%
#sort from highest revenue to lower
top_products = top_products.sort_values(by="Revenue", ascending=False)

# %%
# Group by product description and sum the total revenue for each product
top_products = df_clean.groupby("Description")["Revenue"].sum().reset_index()

# %%
# Sort from highest revenue to lowest
top_products = top_products.sort_values(by="Revenue", ascending=False)

# Keep only the top 10 products
top_10_products = top_products.head(10)

# Show the result
top_10_products
# Out:
#                              Description    Revenue
# 1067                      DOTCOM POSTAGE  206248.77
# 2853            REGENCY CAKESTAND 3 TIER  174484.74
# 2387         PAPER CRAFT , LITTLE BIRDIE  168469.60
# 3844  WHITE HANGING HEART T-LIGHT HOLDER  106292.77
# 2413                       PARTY BUNTING   99504.33
# 1816             JUMBO BAG RED RETROSPOT   94340.05
# 2052      MEDIUM CERAMIC TOP STORAGE JAR   81700.92
# 2192                              Manual   78112.82
# 2692                             POSTAGE   78101.88
# 2741                  RABBIT NIGHT LIGHT   66964.99

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.barh(top_10_products["Description"], top_10_products["Revenue"], color="skyblue")
plt.xlabel("Revenue")
plt.ylabel("Product")
plt.title("Top 10 Products by Revenue")
plt.gca().invert_yaxis()   # highest value appears at the top
plt.tight_layout()
plt.show()

# %%
top_countries = df_clean.groupby("Country")["Revenue"].sum().reset_index()
top_countries = top_countries.sort_values(by="Revenue", ascending=False)
top_10_countries = top_countries.head(10)

plt.figure(figsize=(10, 5))
plt.bar(top_10_countries["Country"], top_10_countries["Revenue"], color="orange")
plt.xlabel("Country")
plt.ylabel("Revenue")
plt.title("Top 10 Countries by Revenue")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
